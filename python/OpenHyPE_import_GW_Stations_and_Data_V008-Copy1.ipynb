# %% [markdown]
# # NRW Groundwater Data - OpenHygrisC Data Engineering
#
# Data from <br>
# **[LANUV](https://www.lanuv.nrw.de/): Landesamt für Natur, Umwelt und Verbraucherschutz Nordrhein-Westfalen** <br>
# (State Office for Nature, Environment and Consumer Protection NRW)
#
# * LANUV groundwater web pages: https://www.lanuv.nrw.de/umwelt/wasser/grundwasser
#
# Groundwater data: https://www.lanuv.nrw.de/umwelt/wasser/grundwasser/grundwasserstand/grundwasserdaten-online
#
# ELWAS-WEB NRW - Infos zu den Grundwasserkörpern (YouTube): https://www.youtube.com/watch?v=4wFKIu622rk
#
# In the database HygrisC the LANUV provides groundwater quality and quantity data for most groundwater wells in NRW. The groundwater wells are partly owned and operated by NRW, partly by other parties.
# The measurement intervals are usually annual. Some groundwater well are sampled more frequently.
#
# WRRL: EU Wasserrahmenrichtlinie, EU Water Framework Directive
#
# The quality data is based on chemical analyses of groundwater samples. The quantity data is based on groundwater level measurement.
#
#
# OpenHygrisC Data: https://www.opengeodata.nrw.de/produkte/umwelt_klima/wasser/grundwasser/hygrisc/
#
# **Download the NRW groundwater data zip file**:
# <br>
# https://www.opengeodata.nrw.de/produkte/umwelt_klima/wasser/grundwasser/hygrisc/OpenHygrisC_gw-messstellen-messwerte_EPSG25832_CSV.zip
#
# The zip archive contains gw station info, a catalog of possible physico-chemical analysis parameters, and the measured data.
#
# ## Coordinate Obfuscation
#
# Some coordinate data in the gw station info reveal difficulties. The coordinate reference system (CRS) used is the projected metric based
# EPSG:25832 ( ETRS89 / UTM zone 32N).
# The dataframe coordinate columns `e32` (easting) and `n32` (northing) are of data type object (not numeric).
#
# The resolution is 1m but many coordinates are obscurred because of privacy issues to a precision of 100m. A few coordinates are missing, i.e. either empty (nan) or filled with `xx`.
#
#
# The coordinate columns e32 and n32 are of data type object/string. Four cases must be distinguished:
#
# * Most strings are in a regular number format and can be converted to float right away (case (1) and (2) in the table)
# * Other coordinate strings are obfuscated by replacing the two least significant decimal places with the characters "xx". This usually happens when a groundwater well is on private property. The coordinates are made less precise to respect privacy. The remaining coordinate information is still usable. The precision is limited to 100 meters. The uncertainty is +- 50m. (case (3) in the table)
# * In some cases no coordinate infomation is given at all. In these cases the coordinate strings are just "xx". (case (4) in the table)
# * In a very few cases the coordinate columns are empty, i.e. NaN (Null). (case (5) in the table)
#
# The following table shows representative cases.
#
#
# | case |   messstelle_id | e32    | n32     | grundstueck   |
# |-----:|----------------:|-------:|--------:|:--------------|
# |  (1) |        10000094 | 292868 | 5632572 | oeffentlich   |
# |  (2) |        10000045 | 299399 | 5650595 | privat        |
# |  (3) |        10000033 | 3070xx | 56583xx | privat        |
# |  (4) |        47247101 | xx     | xx      |               |
# |  (5) |        79921802 | nan    | nan     |               |
#
# Case (1) and (2) have coordinate strings which can be immediately converted to integer or float with 1m precision. Case (3) shows coordinate obfuscation to a precision to 100m. The digits representing tens and ones are anonymized. Case (4) and (5) show useless coordinate information.
#
# How to deal with non-anonymized data:
#
# "299399" (string, prec. 1) => 299399.0 (float)
#
# How to deal with anonymization:
#
# 307000 <= 3070xx <= 307099
#
# "3070xx" (string, prec. 100) => 307050 (float, +- 50m)

# %%
#!conda env list

# %% [markdown]
# ## Correct wrong `PROJ_LIB` environment variable value
#
# This problem seems to occur on Windows when using the OSGeo4W installer. The environment variable must point to a user specific directory and according to the activated conda environment, e.g. `PROJ_LIB=C:\Users\<username>\Anaconda3\envs\geo\Library\share\proj`

# %%
import os
os.environ['proj_lib']
# Out:
# 'C:\\Program Files\\PostgreSQL\\13\\share\\contrib\\postgis-3.4\\proj'

# %%
# Correct wrong environment variable value occurring when using OSGeo4W installer
conda_prefix = os.environ['conda_prefix']
print(f"CONDA_PREFIX: {conda_prefix:s}")
os.environ['proj_lib'] = conda_prefix + r"\Library\share\proj"
proj_lib = os.environ['proj_lib']
print(f"New env var value: \nPROJ_LIB={proj_lib:s}")
# Out:
# CONDA_PREFIX: C:\Users\shrey\anaconda3\envs\geo
# New env var value:
# PROJ_LIB=C:\Users\shrey\anaconda3\envs\geo\Library\share\proj

# %% [markdown]
# ## Imports

# %%
# CORRECT THE WRONG PYPROJ PATH FIRST! OTHERWISE GEOPANDAS DOES NOT LOAD!
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## Data Directories and Files

# %%
station_data_in_dir = r"../data/OpenGeodata.NRW/OpenHygrisC/OpenHygrisC_gw-messstelle_EPSG25832_CSV/"
for elt in os.listdir(data_in_dir): print(elt)
# Out:
# .ipynb_checkpoints
# OpenHygrisC_gw-chemischer-messwert_2020-2029_EPSG25832_CSV
# OpenHygrisC_gw-messstelle.csv
# OpenHygrisC_gw-messstelle1-utf8.csv
# OpenHygrisC_gw-messstelle1.csv

# %% [markdown]
# ## GW Station Data

# %%
gw_station_fname = r"OpenHygrisC_gw-messstelle.csv"
gw_station_pfname = station_data_in_dir + "/" + gw_station_fname
print(f"Stationsdaten:  {gw_station_pfname:s}")
# Out:
# Stationsdaten:  ../data/OpenGeodata.NRW/OpenHygrisC/OpenHygrisC_gw-messstelle_EPSG25832_CSV//OpenHygrisC_gw-messstelle.csv

# %%
df = pd.read_csv(gw_station_pfname, sep = ";", encoding="cp1252", index_col=["messstelle_id"])

# %%
df.sort_index(ascending=True, inplace=True)

# %%
num_total = df.shape[0]
df.shape
# Out:
# (72528, 38)

# %%
print(f"{pd.get_option('display.max_columns') = }")
pd.set_option("display.max_columns", None)
print(f"{pd.get_option('display.max_columns') = }")
# Out:
# pd.get_option('display.max_columns') = None
# pd.get_option('display.max_columns') = None

# %%
df.head()
# Out:
#                sl_nr                         name     e32      n32  \
# messstelle_id
# 10000008       70796  P3-BSR/Mariaschacht P 5 neu  3068XX  56254XX
# 10000010           1          SCHERPENSEEL NR 1    2935XX  56452XX
# 10000021           2          Bellinghoven Nr. 2   312776  5660432
# 10000033           3          Doveren Nr. 3        3070XX  56583XX
# 10000045           4          Geilenkirchen Nr. 5  299399  5650595
#
#                gw_stockwerk grundstueck gemeinde_id gwhorizont_id  \
# messstelle_id
# 10000008                1.0                05334032           NaN
# 10000010                1.0      privat    05370028            6D
# 10000021                1.0      privat    05370004            14
# 10000033                1.0      privat    05370020            16
# 10000045                1.0      privat    05370012            10
#
#                                               gwhorizont gwleiter_id gwleiter  \
# messstelle_id
# 10000008                                             NaN         NaN      NaN
# 10000010                                  Neurather Sand         NaN      NaN
# 10000021                           Ältere Hauptterrassen         NaN      NaN
# 10000033       Jüngere Hauptterrassen mit Lößauflagerung         NaN      NaN
# 10000045                                 Sande und Kiese         NaN      NaN
#
#                               einrichtungsgrund gwk_lage_auf_id gwk_lage_id  \
# messstelle_id
# 10000008       GW-Beschaffenheit                     01.07.2016      282_11
# 10000010       LGD                                   01.07.2016       28_04
# 10000021       LGD                                   01.07.2016      286_07
# 10000033       LGD                                   01.07.2016      282_01
# 10000045       LGD                                   01.07.2016      282_03
#
#               gwk_monitoring_auf_id gwk_monitoring_id  \
# messstelle_id
# 10000008                 01.07.2016            282_11
# 10000010                 01.07.2016             28_04
# 10000021                 01.07.2016            286_07
# 10000033                 01.07.2016            282_01
# 10000045                 01.07.2016            282_03
#
#                                    messprogramm  \
# messstelle_id
# 10000008       RWÜ (Messstelle f. GWÜ geeignet)
# 10000010             Grundwassergüteüberwachung
# 10000021                                    NaN
# 10000033           Emittentenmst./Anlagenüberw.
# 10000045                                    NaN
#
#                           turnus_wasserstand freigabe_wstd freigabe_chemie  \
# messstelle_id
# 10000008                           monatlich          nein            nein
# 10000010       Messstelle besteht nicht mehr            ja              ja
# 10000021                  Messstelle inaktiv            ja            nein
# 10000033                  Messstelle inaktiv            ja            nein
# 10000045       Messstelle besteht nicht mehr            ja            nein
#
#               freigabe_lage wasserstandsmessstelle guetemessstelle  \
# messstelle_id
# 10000008               nein                     ja              ja
# 10000010               nein                     ja              ja
# 10000021                 ja                     ja            nein
# 10000033               nein                     ja              ja
# 10000045                 ja                     ja            nein
#
#               im_wrrl_messnetz_chemie im_wrrl_messnetz_wasserstand  \
# messstelle_id
# 10000008                         nein                         nein
# 10000010                         nein                         nein
# 10000021                         nein                         nein
# 10000033                         nein                         nein
# 10000045                         nein                         nein
#
#                                  messstellenart           wasserart labor  \
# messstelle_id
# 10000008       GW-Messstelle                     reines Grundwasser     -
# 10000010       GW-Messstelle                           keine Angabe     -
# 10000021       Schachtbrunnen                                   NaN   NaN
# 10000033       Schachtbrunnen                          keine Angabe     -
# 10000045                  Vertikalfilterbrunnen                 NaN   NaN
#
#               beobachtung_wasserstand  \
# messstelle_id
# 10000008                            -
# 10000010                            -
# 10000021                            -
# 10000033                            -
# 10000045                            -
#
#                                                      eigentuemer  \
# messstelle_id
# 10000008       BSR Schotterwerk                              ...
# 10000010       Land NRW                                      ...
# 10000021       keine Angabe                                  ...
# 10000033       Privatperson                                  ...
# 10000045       Privatperson                                  ...
#
#                                                        betreiber  \
# messstelle_id
# 10000008       Enwor GmbH                                    ...
# 10000010       keine Angabe                                  ...
# 10000021       keine Angabe                                  ...
# 10000033       keine Angabe                                  ...
# 10000045       keine Angabe                                  ...
#
#                filterlaenge_cm  sumpfrohrlaenge_cm  ausbaudurchmesser_mm  \
# messstelle_id
# 10000008                 700.0                 0.0                  80.0
# 10000010                 400.0                 NaN                 100.0
# 10000021                   NaN                 NaN                1000.0
# 10000033                   NaN                 NaN                1000.0
# 10000045                 200.0                 NaN                1000.0
#
#               historischer_ruhe_wsp  einbaulaenge_cm  oberkante_filter_cm  \
# messstelle_id
# 10000008                        NaN           1650.0              20973.0
# 10000010                        NaN           4936.0               7731.0
# 10000021                        NaN           1411.0               7885.0
# 10000033                        NaN            755.0               4847.0
# 10000045                        NaN           1079.0               6140.0
#
#                unterkante_filter_cm
# messstelle_id
# 10000008                    20273.0
# 10000010                     7331.0
# 10000021                     7885.0
# 10000033                     4847.0
# 10000045                     5940.0

# %%
#df[df["grundstueck"]=="oeffentlich"].head()

# %% [markdown]
# ## Challenge: Coordinates obfuscation
#
# The coordinate columns e32 and n32 are of data type string. Four cases must be distinguished:
#
# (1) Most strings are in a regular number format and can be converted to float right away.
#
# (2) Other coordinate strings are obfuscated by replacing the two least significant digits with the characters "xx". This usually happens when a groundwater well is on private property. The coordinates are made less precise to respect privacy. The remaining coordinate information is still usable. The precision is limited to 100 meters. The uncertainty is +- 50m.
#
# (3) In some cases no coordinate infomation is given at all. In these cases the coordinate strings are just "xx".
#
# (4) In a very few cases the coordinate columns are empty, i.e. NaN (Null).

# %%
# These four groundwater wells summarize the coordinate problems.
#df_coord_problem=df.loc[[10000094, 10000045, 10000033, 47247101, 79921802],["e32","n32", "grundstueck"]]
#df_coord_problem

# %%
# forma table as markdown
#from tabulate import tabulate
#print(tabulate(df_coord_problem, tablefmt="pipe", headers="keys"))

# %% [markdown]
# |   messstelle_id | e32    | n32     | grundstueck   |
# |----------------:|:-------|:--------|:--------------|
# |        10000094 | 292868 | 5632572 | oeffentlich   |
# |        10000045 | 299399 | 5650595 | privat        |
# |        10000033 | 3070xx | 56583xx | privat        |
# |        47247101 | xx     | xx      |               |
# |        79921802 | nan    | nan     |               |

# %% [markdown]
# **Boolean indexes are used to filter the data according to the cases (1) to (4).**

# %%
df
# Out:
#                sl_nr                         name     e32      n32  \
# messstelle_id
# 10000008       70796  P3-BSR/Mariaschacht P 5 neu  3068XX  56254XX
# 10000010           1          SCHERPENSEEL NR 1    2935XX  56452XX
# 10000021           2          Bellinghoven Nr. 2   312776  5660432
# 10000033           3          Doveren Nr. 3        3070XX  56583XX
# 10000045           4          Geilenkirchen Nr. 5  299399  5650595
# ...              ...                          ...     ...      ...
# 289382518      72729          Hackenbroich H20H    345602  5659991
# 289382520      72730          Hackenbroich H20H    345602  5659991
# 289382610      72927          Hackenbroich H25T    345313  5660272
# 289382622      72928          Hackenbroich H25T    345313  5660272
# 289382713      72731          Hackenbroich H30     344170  5660121
#
#                gw_stockwerk grundstueck gemeinde_id gwhorizont_id  \
# messstelle_id
# 10000008                1.0                05334032           NaN
# 10000010                1.0      privat    05370028            6D
# 10000021                1.0      privat    05370004            14
# 10000033                1.0      privat    05370020            16
# 10000045                1.0      privat    05370012            10
# ...                     ...         ...         ...           ...
# 289382518               1.0                05162004            19
# 289382520               1.0                05162004            19
# 289382610               1.0                05162004            19
# 289382622               1.0                05162004            19
# 289382713               1.0                05162004            19
#
#                                               gwhorizont gwleiter_id gwleiter  \
# messstelle_id
# 10000008                                             NaN         NaN      NaN
# 10000010                                  Neurather Sand         NaN      NaN
# 10000021                           Ältere Hauptterrassen         NaN      NaN
# 10000033       Jüngere Hauptterrassen mit Lößauflagerung         NaN      NaN
# 10000045                                 Sande und Kiese         NaN      NaN
# ...                                                  ...         ...      ...
# 289382518             Niederterrassen mit Lößauflagerung         NaN      NaN
# 289382520             Niederterrassen mit Lößauflagerung         NaN      NaN
# 289382610             Niederterrassen mit Lößauflagerung         NaN      NaN
# 289382622             Niederterrassen mit Lößauflagerung         NaN      NaN
# 289382713             Niederterrassen mit Lößauflagerung         NaN      NaN
#
#                               einrichtungsgrund gwk_lage_auf_id gwk_lage_id  \
# messstelle_id
# 10000008       GW-Beschaffenheit                     01.07.2016      282_11
# 10000010       LGD                                   01.07.2016       28_04
# 10000021       LGD                                   01.07.2016      286_07
# 10000033       LGD                                   01.07.2016      282_01
# 10000045       LGD                                   01.07.2016      282_03
# ...                                         ...             ...         ...
# 289382518      keine Angabe                          01.07.2016       27_20
# 289382520      keine Angabe                          01.07.2016       27_20
# 289382610      keine Angabe                          01.07.2016      274_01
# 289382622      keine Angabe                          01.07.2016      274_01
# 289382713      keine Angabe                          01.07.2016      274_01
#
#               gwk_monitoring_auf_id gwk_monitoring_id  \
# messstelle_id
# 10000008                 01.07.2016            282_11
# 10000010                 01.07.2016             28_04
# 10000021                 01.07.2016            286_07
# 10000033                 01.07.2016            282_01
# 10000045                 01.07.2016            282_03
# ...                             ...               ...
# 289382518                01.07.2016             27_20
# 289382520                01.07.2016             27_20
# 289382610                01.07.2016            274_01
# 289382622                01.07.2016            274_01
# 289382713                01.07.2016            274_01
#
#                                    messprogramm  \
# messstelle_id
# 10000008       RWÜ (Messstelle f. GWÜ geeignet)
# 10000010             Grundwassergüteüberwachung
# 10000021                                    NaN
# 10000033           Emittentenmst./Anlagenüberw.
# 10000045                                    NaN
# ...                                         ...
# 289382518                                   NaN
# 289382520                                   NaN
# 289382610                                   NaN
# 289382622                                   NaN
# 289382713                                   NaN
#
#                           turnus_wasserstand freigabe_wstd freigabe_chemie  \
# messstelle_id
# 10000008                           monatlich          nein            nein
# 10000010       Messstelle besteht nicht mehr            ja              ja
# 10000021                  Messstelle inaktiv            ja            nein
# 10000033                  Messstelle inaktiv            ja            nein
# 10000045       Messstelle besteht nicht mehr            ja            nein
# ...                                      ...           ...             ...
# 289382518                       halbjährlich          nein            nein
# 289382520                       halbjährlich          nein            nein
# 289382610                 Messstelle inaktiv          nein            nein
# 289382622                 Messstelle inaktiv          nein            nein
# 289382713                       halbjährlich          nein            nein
#
#               freigabe_lage wasserstandsmessstelle guetemessstelle  \
# messstelle_id
# 10000008               nein                     ja              ja
# 10000010               nein                     ja              ja
# 10000021                 ja                     ja            nein
# 10000033               nein                     ja              ja
# 10000045                 ja                     ja            nein
# ...                     ...                    ...             ...
# 289382518                ja                     ja            nein
# 289382520                ja                     ja            nein
# 289382610                ja                     ja            nein
# 289382622                ja                     ja            nein
# 289382713                ja                     ja            nein
#
#               im_wrrl_messnetz_chemie im_wrrl_messnetz_wasserstand  \
# messstelle_id
# 10000008                         nein                         nein
# 10000010                         nein                         nein
# 10000021                         nein                         nein
# 10000033                         nein                         nein
# 10000045                         nein                         nein
# ...                               ...                          ...
# 289382518                        nein                         nein
# 289382520                        nein                         nein
# 289382610                        nein                         nein
# 289382622                        nein                         nein
# 289382713                        nein                         nein
#
#                                  messstellenart           wasserart labor  \
# messstelle_id
# 10000008       GW-Messstelle                     reines Grundwasser     -
# 10000010       GW-Messstelle                           keine Angabe     -
# 10000021       Schachtbrunnen                                   NaN   NaN
# 10000033       Schachtbrunnen                          keine Angabe     -
# 10000045                  Vertikalfilterbrunnen                 NaN   NaN
# ...                                         ...                 ...   ...
# 289382518      GW-Messstelle                                    NaN   NaN
# 289382520      GW-Messstelle                                    NaN   NaN
# 289382610      GW-Messstelle                                    NaN   NaN
# 289382622      GW-Messstelle                                    NaN   NaN
# 289382713      GW-Messstelle                                    NaN   NaN
#
#               beobachtung_wasserstand  \
# messstelle_id
# 10000008                            -
# 10000010                            -
# 10000021                            -
# 10000033                            -
# 10000045                            -
# ...                               ...
# 289382518                           -
# 289382520                           -
# 289382610                           -
# 289382622                           -
# 289382713                           -
#
#                                                      eigentuemer  \
# messstelle_id
# 10000008       BSR Schotterwerk                              ...
# 10000010       Land NRW                                      ...
# 10000021       keine Angabe                                  ...
# 10000033       Privatperson                                  ...
# 10000045       Privatperson                                  ...
# ...                                                          ...
# 289382518                                                    NaN
# 289382520                                                    NaN
# 289382610                                                    NaN
# 289382622                                                    NaN
# 289382713                                                    NaN
#
#                                                        betreiber  \
# messstelle_id
# 10000008       Enwor GmbH                                    ...
# 10000010       keine Angabe                                  ...
# 10000021       keine Angabe                                  ...
# 10000033       keine Angabe                                  ...
# 10000045       keine Angabe                                  ...
# ...                                                          ...
# 289382518                                                    NaN
# 289382520                                                    NaN
# 289382610                                                    NaN
# 289382622                                                    NaN
# 289382713                                                    NaN
#
#                filterlaenge_cm  sumpfrohrlaenge_cm  ausbaudurchmesser_mm  \
# messstelle_id
# 10000008                 700.0                 0.0                  80.0
# 10000010                 400.0                 NaN                 100.0
# 10000021                   NaN                 NaN                1000.0
# 10000033                   NaN                 NaN                1000.0
# 10000045                 200.0                 NaN                1000.0
# ...                        ...                 ...                   ...
# 289382518               2000.0               100.0                  65.0
# 289382520               2000.0               100.0                 150.0
# 289382610               1000.0                 NaN                  65.0
# 289382622                900.0                 NaN                  65.0
# 289382713               1800.0                 NaN                 125.0
#
#               historischer_ruhe_wsp  einbaulaenge_cm  oberkante_filter_cm  \
# messstelle_id
# 10000008                        NaN           1650.0              20973.0
# 10000010                        NaN           4936.0               7731.0
# 10000021                        NaN           1411.0               7885.0
# 10000033                        NaN            755.0               4847.0
# 10000045                        NaN           1079.0               6140.0
# ...                             ...              ...                  ...
# 289382518                       NaN           3070.0               3442.0
# 289382520                       NaN           3070.0               3431.0
# 289382610                       NaN           1700.0               3659.0
# 289382622                       NaN           2650.0               2608.0
# 289382713                       NaN           2300.0               3830.0
#
#                unterkante_filter_cm
# messstelle_id
# 10000008                    20273.0
# 10000010                     7331.0
# 10000021                     7885.0
# 10000033                     4847.0
# 10000045                     5940.0
# ...                             ...
# 289382518                    1442.0
# 289382520                    1431.0
# 289382610                    2659.0
# 289382622                    1708.0
# 289382713                    2030.0
#
# [72528 rows x 38 columns]

# %%
# Add column for precision
df["genau"] = 0

# (1) If the coord data is numeric then the precision is 1m
idx_coords_1m_prec = (df["e32"].str.isnumeric() == True)

# (3,4) Some stations don't have coordinates
# e32 and n32 strings are either NaN (Null) or "xx"
idx_coords_missing = (df["e32"].str.len() < 6) | (df["e32"].isnull() == True)

# (2) If coord data is avaliable but not numeric, then the numbers have been obscured with "XX" for the two least significant decimals.
idx_coords_100m_prec = ~idx_coords_missing &  ~(df["e32"].str.isnumeric() == True)

# %%
df[idx_coords_missing]
# Out:
#                sl_nr                 name  e32  n32  gw_stockwerk grundstueck  \
# messstelle_id
# 36446518       47111  WA-Lörick LR - RMM    XX   XX           NaN
# 36487600       46659  Wittlaer              XX   XX           NaN
# 47199003       47636  Sammelleitung 1-7     XX   XX           NaN
# 47200005       47638  Sammelleitung 10-20   XX   XX           NaN
# 47202002       47647  Sammelleitung 21-30   XX   XX           NaN
# 47247101       46769  RM-Moers Gerdt        XX   XX           NaN
# 47299009       47658  RM-Bucholtwelmen      XX   XX           NaN
# 59621035       46215  RM-Brunnen Stortel    XX   XX           NaN
# 68011003       47697  WW.HALTERNHAARD-MI    XX   XX           NaN
# 68012007       14582  WW.HALTERNWEST-MI     XX   XX           1.0
# 68013103       47705  WW.HALTERN-BRR A      XX   XX           NaN
# 68013206       47706  WW.HALTERN-BRR B      XX   XX           NaN
# 68013309       47707  WW.HALTERN-BRR G      XX   XX           NaN
# 68013401       47708  WW.HALTERN-BRR C/D    XX   XX           NaN
# 68013504       47709  WW.HALTERN-BRR E/F    XX   XX           NaN
# 68013607       47710  WW.HALTERN-BRR H/K    XX   XX           NaN
# 79921802       69491     Etzold_BN_868_SB  NaN  NaN           1.0
# 129700800      45778  RM-Zinse              XX   XX           NaN
#
#               gemeinde_id gwhorizont_id gwhorizont gwleiter_id gwleiter  \
# messstelle_id
# 36446518              NaN           NaN        NaN         NaN      NaN
# 36487600              NaN           NaN        NaN         NaN      NaN
# 47199003              NaN           NaN        NaN         NaN      NaN
# 47200005              NaN           NaN        NaN         NaN      NaN
# 47202002              NaN           NaN        NaN         NaN      NaN
# 47247101              NaN           NaN        NaN         NaN      NaN
# 47299009              NaN           NaN        NaN         NaN      NaN
# 59621035              NaN           NaN        NaN         NaN      NaN
# 68011003              NaN           NaN        NaN         NaN      NaN
# 68012007              NaN           NaN        NaN         NaN      NaN
# 68013103              NaN           NaN        NaN         NaN      NaN
# 68013206              NaN           NaN        NaN         NaN      NaN
# 68013309              NaN           NaN        NaN         NaN      NaN
# 68013401              NaN           NaN        NaN         NaN      NaN
# 68013504              NaN           NaN        NaN         NaN      NaN
# 68013607              NaN           NaN        NaN         NaN      NaN
# 79921802              NaN           NaN        NaN         NaN      NaN
# 129700800             NaN           NaN        NaN         NaN      NaN
#
#                               einrichtungsgrund gwk_lage_auf_id gwk_lage_id  \
# messstelle_id
# 36446518       Eigenüberwachung Wasserwerk                  NaN         NaN
# 36487600       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47199003       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47200005       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47202002       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47247101       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47299009       Eigenüberwachung Wasserwerk                  NaN         NaN
# 59621035       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68011003       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68012007       keine Angabe                                 NaN         NaN
# 68013103       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68013206       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68013309       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68013401       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68013504       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68013607       Eigenüberwachung Wasserwerk                  NaN         NaN
# 79921802       keine Angabe                                 NaN         NaN
# 129700800      Eigenüberwachung Wasserwerk                  NaN         NaN
#
#               gwk_monitoring_auf_id gwk_monitoring_id  \
# messstelle_id
# 36446518                        NaN               NaN
# 36487600                        NaN               NaN
# 47199003                        NaN               NaN
# 47200005                        NaN               NaN
# 47202002                        NaN               NaN
# 47247101                        NaN               NaN
# 47299009                        NaN               NaN
# 59621035                        NaN               NaN
# 68011003                        NaN               NaN
# 68012007                        NaN               NaN
# 68013103                        NaN               NaN
# 68013206                        NaN               NaN
# 68013309                        NaN               NaN
# 68013401                        NaN               NaN
# 68013504                        NaN               NaN
# 68013607                        NaN               NaN
# 79921802                        NaN               NaN
# 129700800                       NaN               NaN
#
#                               messprogramm  turnus_wasserstand freigabe_wstd  \
# messstelle_id
# 36446518       RWÜ (keine GWÜ-Messstellen)  Messstelle inaktiv          nein
# 36487600       RWÜ (keine GWÜ-Messstellen)  Messstelle inaktiv          nein
# 47199003       RWÜ (keine GWÜ-Messstellen)  Messstelle inaktiv          nein
# 47200005       RWÜ (keine GWÜ-Messstellen)  Messstelle inaktiv          nein
# 47202002       RWÜ (keine GWÜ-Messstellen)  Messstelle inaktiv          nein
# 47247101       RWÜ (keine GWÜ-Messstellen)  Messstelle inaktiv          nein
# 47299009       RWÜ (keine GWÜ-Messstellen)  Messstelle inaktiv          nein
# 59621035       RWÜ (keine GWÜ-Messstellen)                 NaN          nein
# 68011003       RWÜ (keine GWÜ-Messstellen)                 NaN          nein
# 68012007       RWÜ (keine GWÜ-Messstellen)                 NaN          nein
# 68013103       RWÜ (keine GWÜ-Messstellen)                 NaN          nein
# 68013206       RWÜ (keine GWÜ-Messstellen)                 NaN          nein
# 68013309       RWÜ (keine GWÜ-Messstellen)                 NaN          nein
# 68013401       RWÜ (keine GWÜ-Messstellen)                 NaN          nein
# 68013504       RWÜ (keine GWÜ-Messstellen)                 NaN          nein
# 68013607       RWÜ (keine GWÜ-Messstellen)                 NaN          nein
# 79921802                               NaN       Einzelmessung          nein
# 129700800      RWÜ (keine GWÜ-Messstellen)                 NaN          nein
#
#               freigabe_chemie freigabe_lage wasserstandsmessstelle  \
# messstelle_id
# 36446518                 nein          nein                     ja
# 36487600                 nein          nein                     ja
# 47199003                 nein          nein                     ja
# 47200005                 nein          nein                     ja
# 47202002                 nein          nein                     ja
# 47247101                 nein          nein                     ja
# 47299009                 nein          nein                     ja
# 59621035                 nein          nein                   nein
# 68011003                 nein          nein                   nein
# 68012007                 nein          nein                   nein
# 68013103                 nein          nein                   nein
# 68013206                 nein          nein                   nein
# 68013309                 nein          nein                   nein
# 68013401                 nein          nein                   nein
# 68013504                 nein          nein                   nein
# 68013607                 nein          nein                   nein
# 79921802                 nein            ja                     ja
# 129700800                nein          nein                   nein
#
#               guetemessstelle im_wrrl_messnetz_chemie  \
# messstelle_id
# 36446518                   ja                    nein
# 36487600                   ja                    nein
# 47199003                   ja                    nein
# 47200005                   ja                    nein
# 47202002                   ja                    nein
# 47247101                   ja                    nein
# 47299009                   ja                    nein
# 59621035                   ja                    nein
# 68011003                   ja                    nein
# 68012007                   ja                    nein
# 68013103                   ja                    nein
# 68013206                   ja                    nein
# 68013309                   ja                    nein
# 68013401                   ja                    nein
# 68013504                   ja                    nein
# 68013607                   ja                    nein
# 79921802                 nein                    nein
# 129700800                  ja                    nein
#
#               im_wrrl_messnetz_wasserstand                    messstellenart  \
# messstelle_id
# 36446518                              nein  Sammelmessstelle
# 36487600                              nein  Sammelmessstelle
# 47199003                              nein  Sammelmessstelle
# 47200005                              nein  Sammelmessstelle
# 47202002                              nein  Sammelmessstelle
# 47247101                              nein  Rohmischwassermessstelle
# 47299009                              nein  Rohmischwassermessstelle
# 59621035                              nein  Rohmischwassermessstelle
# 68011003                              nein  Sammelmessstelle
# 68012007                              nein  Sammelmessstelle
# 68013103                              nein  Sammelmessstelle
# 68013206                              nein  Sammelmessstelle
# 68013309                              nein  Sammelmessstelle
# 68013401                              nein  Sammelmessstelle
# 68013504                              nein  Sammelmessstelle
# 68013607                              nein  Sammelmessstelle
# 79921802                              nein             Vertikalfilterbrunnen
# 129700800                             nein  Rohmischwassermessstelle
#
#                   wasserart labor beobachtung_wasserstand  \
# messstelle_id
# 36446518       keine Angabe     -                       -
# 36487600       keine Angabe     -                       -
# 47199003       keine Angabe     -                       -
# 47200005       keine Angabe     -                       -
# 47202002       keine Angabe     -                       -
# 47247101       keine Angabe     -                       -
# 47299009       keine Angabe     -                       -
# 59621035       keine Angabe     -                     NaN
# 68011003       keine Angabe     -                     NaN
# 68012007       keine Angabe     -                     NaN
# 68013103       keine Angabe     -                     NaN
# 68013206       keine Angabe     -                     NaN
# 68013309       keine Angabe     -                     NaN
# 68013401       keine Angabe     -                     NaN
# 68013504       keine Angabe     -                     NaN
# 68013607       keine Angabe     -                     NaN
# 79921802                NaN   NaN                       -
# 129700800      keine Angabe     -                     NaN
#
#                                                      eigentuemer  \
# messstelle_id
# 36446518                                                     NaN
# 36487600                                                     NaN
# 47199003                                                     NaN
# 47200005                                                     NaN
# 47202002                                                     NaN
# 47247101                                                     NaN
# 47299009                                                     NaN
# 59621035                                                     NaN
# 68011003                                                     NaN
# 68012007                                                     NaN
# 68013103                                                     NaN
# 68013206                                                     NaN
# 68013309                                                     NaN
# 68013401                                                     NaN
# 68013504                                                     NaN
# 68013607                                                     NaN
# 79921802                                                     NaN
# 129700800      Wasserverband Siegen-Wittgenstein             ...
#
#                                                        betreiber  \
# messstelle_id
# 36446518                                                     NaN
# 36487600                                                     NaN
# 47199003                                                     NaN
# 47200005                                                     NaN
# 47202002                                                     NaN
# 47247101                                                     NaN
# 47299009                                                     NaN
# 59621035                                                     NaN
# 68011003                                                     NaN
# 68012007                                                     NaN
# 68013103                                                     NaN
# 68013206                                                     NaN
# 68013309                                                     NaN
# 68013401                                                     NaN
# 68013504                                                     NaN
# 68013607                                                     NaN
# 79921802                                                     NaN
# 129700800      Wasserverband Siegen-Wittgenstein             ...
#
#                filterlaenge_cm  sumpfrohrlaenge_cm  ausbaudurchmesser_mm  \
# messstelle_id
# 36446518                   NaN                 NaN                   NaN
# 36487600                   NaN                 NaN                   NaN
# 47199003                   NaN                 NaN                   NaN
# 47200005                   NaN                 NaN                   NaN
# 47202002                   NaN                 NaN                   NaN
# 47247101                   NaN                 NaN                   NaN
# 47299009                   NaN                 NaN                   NaN
# 59621035                   NaN                 NaN                   NaN
# 68011003                   NaN                 NaN                   NaN
# 68012007                   NaN                 NaN                   NaN
# 68013103                   NaN                 NaN                   NaN
# 68013206                   NaN                 NaN                   NaN
# 68013309                   NaN                 NaN                   NaN
# 68013401                   NaN                 NaN                   NaN
# 68013504                   NaN                 NaN                   NaN
# 68013607                   NaN                 NaN                   NaN
# 79921802                   NaN                 NaN                   NaN
# 129700800                  NaN                 NaN                   NaN
#
#               historischer_ruhe_wsp  einbaulaenge_cm  oberkante_filter_cm  \
# messstelle_id
# 36446518                        NaN              NaN                  NaN
# 36487600                        NaN              NaN                  NaN
# 47199003                        NaN              NaN                  NaN
# 47200005                        NaN              NaN                  NaN
# 47202002                        NaN              NaN                  NaN
# 47247101                        NaN              NaN                  NaN
# 47299009                        NaN              NaN                  NaN
# 59621035                        NaN              NaN                  NaN
# 68011003                        NaN              NaN                  NaN
# 68012007                        NaN              NaN                  NaN
# 68013103                        NaN              NaN                  NaN
# 68013206                        NaN              NaN                  NaN
# 68013309                        NaN              NaN                  NaN
# 68013401                        NaN              NaN                  NaN
# 68013504                        NaN              NaN                  NaN
# 68013607                        NaN              NaN                  NaN
# 79921802                        NaN           1450.0               3650.0
# 129700800                       NaN              NaN                  NaN
#
#                unterkante_filter_cm  genau
# messstelle_id
# 36446518                        NaN      0
# 36487600                        NaN      0
# 47199003                        NaN      0
# 47200005                        NaN      0
# 47202002                        NaN      0
# 47247101                        NaN      0
# 47299009                        NaN      0
# 59621035                        NaN      0
# 68011003                        NaN      0
# 68012007                        NaN      0
# 68013103                        NaN      0
# 68013206                        NaN      0
# 68013309                        NaN      0
# 68013401                        NaN      0
# 68013504                        NaN      0
# 68013607                        NaN      0
# 79921802                     3650.0      0
# 129700800                       NaN      0

# %% [markdown]
# **Convert the strings to floats where possible. No data values are represented as negative numbers.**

# %%
df.loc[idx_coords_1m_prec,"e32num"] = df.loc[idx_coords_1m_prec,"e32"].astype(float)
df.loc[idx_coords_1m_prec,"n32num"] = df.loc[idx_coords_1m_prec,"n32"].astype(float)
df.loc[idx_coords_1m_prec, "genau"] = 1

# %%
df.loc[idx_coords_100m_prec,"e32num"] = (df.loc[idx_coords_100m_prec,"e32"].str[:-2]+"50").astype(float)
df.loc[idx_coords_100m_prec,"n32num"] = (df.loc[idx_coords_100m_prec,"n32"].str[:-2]+"50").astype(float)
df.loc[idx_coords_100m_prec, "genau"] = 100

# %%
df.loc[idx_coords_missing,"e32num"] = -999.9
df.loc[idx_coords_missing,"n32num"] = -999.9
df.loc[idx_coords_missing, "genau"] = -999

# %%
# check if all records have been matched
num_of_1m_prec = df[df["genau"] == 1].shape[0]
num_of_100m_prec = df[df["genau"] == 100].shape[0]
num_of_no_prec = df[df["genau"] == -999].shape[0]

num_check = num_of_1m_prec + num_of_100m_prec + num_of_no_prec

print(f"total num of recs:                        {num_total:6d}")
print(f"number of recs with 1m coord precision:   {num_of_1m_prec:6d}")
print(f"number of recs with 100m coord precision: {num_of_100m_prec:6d}")
print(f"number of recs with no coords:            {num_of_no_prec:6d}")
print(f"check sum:                                {num_check:6d}")

assert num_check == num_total, "ERROR. Mismatch in numbers of stations"
# Out:
# total num of recs:                         72528
# number of recs with 1m coord precision:    60885
# number of recs with 100m coord precision:  11625
# number of recs with no coords:                18
# check sum:                                 72528

# %% [markdown]
# **Save the original string as well as the derived numeric columns to a CSV file for checking externally.**

# %%
df[["e32","e32num","n32","n32num","genau"]].to_csv("check.csv")
df[["e32","e32num","n32","n32num","genau"]]
# Out:
#                   e32    e32num      n32     n32num  genau
# messstelle_id
# 10000008       3068XX  306850.0  56254XX  5625450.0    100
# 10000010       2935XX  293550.0  56452XX  5645250.0    100
# 10000021       312776  312776.0  5660432  5660432.0      1
# 10000033       3070XX  307050.0  56583XX  5658350.0    100
# 10000045       299399  299399.0  5650595  5650595.0      1
# ...               ...       ...      ...        ...    ...
# 289382518      345602  345602.0  5659991  5659991.0      1
# 289382520      345602  345602.0  5659991  5659991.0      1
# 289382610      345313  345313.0  5660272  5660272.0      1
# 289382622      345313  345313.0  5660272  5660272.0      1
# 289382713      344170  344170.0  5660121  5660121.0      1
#
# [72528 rows x 5 columns]

# %% [markdown]
# ## Geopandas

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
# remove records without coords
df2 = df[df["genau"] > 0]

# %%
df2.shape
# Out:
# (72510, 41)

# %%
# %%time
gdf = gpd.GeoDataFrame(df2, geometry=gpd.points_from_xy(df2.e32num, df2.n32num), crs="EPSG:25832")
# Out:
# CPU times: total: 62.5 ms
# Wall time: 87.8 ms

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 72510 entries, 10000008 to 289382713
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   sl_nr                         72510 non-null  int64
#  1   name                          72510 non-null  object
#  2   e32                           72510 non-null  object
#  3   n32                           72510 non-null  object
#  4   gw_stockwerk                  54887 non-null  float64
#  5   grundstueck                   72510 non-null  object
#  6   gemeinde_id                   72510 non-null  object
#  7   gwhorizont_id                 28561 non-null  object
#  8   gwhorizont                    28561 non-null  object
#  9   gwleiter_id                   2308 non-null   object
#  10  gwleiter                      2308 non-null   object
#  11  einrichtungsgrund             72510 non-null  object
#  12  gwk_lage_auf_id               72073 non-null  object
#  13  gwk_lage_id                   72073 non-null  object
#  14  gwk_monitoring_auf_id         72198 non-null  object
#  15  gwk_monitoring_id             72198 non-null  object
#  16  messprogramm                  17837 non-null  object
#  17  turnus_wasserstand            68934 non-null  object
#  18  freigabe_wstd                 72510 non-null  object
#  19  freigabe_chemie               72510 non-null  object
#  20  freigabe_lage                 72510 non-null  object
#  21  wasserstandsmessstelle        72510 non-null  object
#  22  guetemessstelle               72510 non-null  object
#  23  im_wrrl_messnetz_chemie       72510 non-null  object
#  24  im_wrrl_messnetz_wasserstand  72510 non-null  object
#  25  messstellenart                72510 non-null  object
#  26  wasserart                     17837 non-null  object
#  27  labor                         17837 non-null  object
#  28  beobachtung_wasserstand       69408 non-null  object
#  29  eigentuemer                   46856 non-null  object
#  30  betreiber                     46236 non-null  object
#  31  filterlaenge_cm               39214 non-null  float64
#  32  sumpfrohrlaenge_cm            32969 non-null  float64
#  33  ausbaudurchmesser_mm          44234 non-null  float64
#  34  historischer_ruhe_wsp         1065 non-null   object
#  35  einbaulaenge_cm               59708 non-null  float64
#  36  oberkante_filter_cm           59708 non-null  float64
#  37  unterkante_filter_cm          59708 non-null  float64
#  38  genau                         72510 non-null  int64
#  39  e32num                        72510 non-null  float64
#  40  n32num                        72510 non-null  float64
#  41  geometry                      72510 non-null  geometry
# dtypes: float64(9), geometry(1), int64(2), object(30)
# memory usage: 23.8+ MB

# %%
gdf.head(3)
# Out:
#                sl_nr                         name     e32      n32  \
# messstelle_id
# 10000008       70796  P3-BSR/Mariaschacht P 5 neu  3068XX  56254XX
# 10000010           1          SCHERPENSEEL NR 1    2935XX  56452XX
# 10000021           2          Bellinghoven Nr. 2   312776  5660432
#
#                gw_stockwerk grundstueck gemeinde_id gwhorizont_id  \
# messstelle_id
# 10000008                1.0                05334032           NaN
# 10000010                1.0      privat    05370028            6D
# 10000021                1.0      privat    05370004            14
#
#                           gwhorizont gwleiter_id gwleiter  \
# messstelle_id
# 10000008                         NaN         NaN      NaN
# 10000010              Neurather Sand         NaN      NaN
# 10000021       Ältere Hauptterrassen         NaN      NaN
#
#                               einrichtungsgrund gwk_lage_auf_id gwk_lage_id  \
# messstelle_id
# 10000008       GW-Beschaffenheit                     01.07.2016      282_11
# 10000010       LGD                                   01.07.2016       28_04
# 10000021       LGD                                   01.07.2016      286_07
#
#               gwk_monitoring_auf_id gwk_monitoring_id  \
# messstelle_id
# 10000008                 01.07.2016            282_11
# 10000010                 01.07.2016             28_04
# 10000021                 01.07.2016            286_07
#
#                                    messprogramm  \
# messstelle_id
# 10000008       RWÜ (Messstelle f. GWÜ geeignet)
# 10000010             Grundwassergüteüberwachung
# 10000021                                    NaN
#
#                           turnus_wasserstand freigabe_wstd freigabe_chemie  \
# messstelle_id
# 10000008                           monatlich          nein            nein
# 10000010       Messstelle besteht nicht mehr            ja              ja
# 10000021                  Messstelle inaktiv            ja            nein
#
#               freigabe_lage wasserstandsmessstelle guetemessstelle  \
# messstelle_id
# 10000008               nein                     ja              ja
# 10000010               nein                     ja              ja
# 10000021                 ja                     ja            nein
#
#               im_wrrl_messnetz_chemie im_wrrl_messnetz_wasserstand  \
# messstelle_id
# 10000008                         nein                         nein
# 10000010                         nein                         nein
# 10000021                         nein                         nein
#
#                                  messstellenart           wasserart labor  \
# messstelle_id
# 10000008       GW-Messstelle                     reines Grundwasser     -
# 10000010       GW-Messstelle                           keine Angabe     -
# 10000021       Schachtbrunnen                                   NaN   NaN
#
#               beobachtung_wasserstand  \
# messstelle_id
# 10000008                            -
# 10000010                            -
# 10000021                            -
#
#                                                      eigentuemer  \
# messstelle_id
# 10000008       BSR Schotterwerk                              ...
# 10000010       Land NRW                                      ...
# 10000021       keine Angabe                                  ...
#
#                                                        betreiber  \
# messstelle_id
# 10000008       Enwor GmbH                                    ...
# 10000010       keine Angabe                                  ...
# 10000021       keine Angabe                                  ...
#
#                filterlaenge_cm  sumpfrohrlaenge_cm  ausbaudurchmesser_mm  \
# messstelle_id
# 10000008                 700.0                 0.0                  80.0
# 10000010                 400.0                 NaN                 100.0
# 10000021                   NaN                 NaN                1000.0
#
#               historischer_ruhe_wsp  einbaulaenge_cm  oberkante_filter_cm  \
# messstelle_id
# 10000008                        NaN           1650.0              20973.0
# 10000010                        NaN           4936.0               7731.0
# 10000021                        NaN           1411.0               7885.0
#
#                unterkante_filter_cm  genau    e32num     n32num  \
# messstelle_id
# 10000008                    20273.0    100  306850.0  5625450.0
# 10000010                     7331.0    100  293550.0  5645250.0
# 10000021                     7885.0      1  312776.0  5660432.0
#
#                                      geometry
# messstelle_id
# 10000008       POINT (306850.000 5625450.000)
# 10000010       POINT (293550.000 5645250.000)
# 10000021       POINT (312776.000 5660432.000)

# %%
# %%time

# This takes 90 secs on my computer!

#gdf.to_file("GW_Stations.gpkg", layer='GW Stations', driver="GPKG")

# %% [markdown]
# ## PostGIS, Inline SQL Magic: `create schema gw`
#
# To store the data in PostGIS/PostgreSQL it is recommended to create a dedicated database "schema" (a kind of name space) to separate relations (tables, views), stored procedures, etc. from the rest of the database. Schemata help to organize the tables and access privileges clearly.

# %%
#!conda install -c conda-forge ipython-sql
# !pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Collecting prettytable (from ipython-sql)
#   Obtaining dependency information for prettytable from https://files.pythonhosted.org/packages/4d/81/316b6a55a0d1f327d04cc7b0ba9d04058cb62de6c3a4d4b0df280cbe3b0b/prettytable-3.9.0-py3-none-any.whl.metadata
#   Downloading prettytable-3.9.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: ipython in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython-sql) (8.16.1)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython-sql) (2.0.22)
# Collecting sqlparse (from ipython-sql)
#   Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#      ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#      ---------------------------------------- 41.2/41.2 kB ? eta 0:00:00
# Requirement already satisfied: six in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: backcall in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython->ipython-sql) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython->ipython-sql) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython->ipython-sql) (2.11.2)
# Requirement already satisfied: stack-data in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython->ipython-sql) (5.11.2)
# Requirement already satisfied: colorama in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from ipython->ipython-sql) (0.4.4)
# Requirement already satisfied: wcwidth in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\shrey\anaconda3\envs\geo\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Downloading prettytable-3.9.0-py3-none-any.whl (27 kB)
# Installing collected packages: sqlparse, prettytable, ipython-sql
# Successfully installed ipython-sql-0.5.0 prettytable-3.9.0 sqlparse-0.4.4

# %%
# %load_ext sql

# %%
print("Connect")
# %sql postgresql://env_master:M123xyz@localhost/env_db
# Out:
# Connect

# %%
# %%sql
# SELECT * FROM information_schema.schemata
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 5 rows affected.
# [('env_db', 'public', 'pg_database_owner', None, None, None, None),
#  ('env_db', 'information_schema', 'postgres', None, None, None, None),
#  ('env_db', 'pg_catalog', 'postgres', None, None, None, None),
#  ('env_db', 'pg_toast', 'postgres', None, None, None, None),
#  ('env_db', 'gw_test', 'env_master', None, None, None, None)]

# %%
# %%sql
# CREATE SCHEMA IF NOT EXISTS gw AUTHORIZATION env_master
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# SELECT * FROM information_schema.schemata;
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 6 rows affected.
# [('env_db', 'public', 'pg_database_owner', None, None, None, None),
#  ('env_db', 'information_schema', 'postgres', None, None, None, None),
#  ('env_db', 'pg_catalog', 'postgres', None, None, None, None),
#  ('env_db', 'pg_toast', 'postgres', None, None, None, None),
#  ('env_db', 'gw', 'env_master', None, None, None, None),
#  ('env_db', 'gw_test', 'env_master', None, None, None, None)]

# %% [markdown]
# ## PostGIS: Upload GeoDataFrame with `gdf.to_postgis()`
#
# Dependencies:
# * psycopg2
# * geoalchemy2

# %%
#!conda install -c conda-forge geoalchemy2 psycopg2

# %%
import sqlalchemy
engine = sqlalchemy.create_engine("postgresql://env_master:M123xyz@localhost/env_db")
# fast_executemany=True
# use_batch_mode=True

# %%
# %%time
gdf.to_postgis(con=engine, name="gw_stations", schema="gw", index=True, chunksize=100, if_exists="replace")
# Out:
# CPU times: total: 1.75 s
# Wall time: 37.6 s

# %% [markdown]
# Create primary key!

# %%
# %%sql
# alter table gw.gw_stations add constraint pk_gw_stations primary key (messstelle_id)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %% [markdown]
# # Groundwater "Quality Data": Chemistry!

# %% [markdown]
# ## Data Directories and Files

# %%
quality_data_in_dir = r"..\data\OpenGeodata.NRW\OpenHygrisC\OpenHygrisC_gw-chemischer-messwert_EPSG25832_CSV\OpenHygrisC_gw-chemischer-messwert_1990-1999_EPSG25832_CSV"
gw_quality_fname = r"\gw-chemischer-messwert-1990-1999.csv"
gw_quality_pfname = quality_data_in_dir + gw_quality_fname
print(f"Qualitätsdaten: {gw_quality_pfname:s}")
# Out:
# Qualitätsdaten: ..\data\OpenGeodata.NRW\OpenHygrisC\OpenHygrisC_gw-chemischer-messwert_EPSG25832_CSV\OpenHygrisC_gw-chemischer-messwert_1990-1999_EPSG25832_CSV\gw-chemischer-messwert-1990-1999.csv

# %%
fh = open(gw_quality_pfname,"r", encoding = "cp1252", newline = '')
s = fh.readline()
s = s.replace('"', '').strip()
header_de = s[1:].split(';')
header_de
# Out:
# ['l_nr',
#  'messstelle_id',
#  'messstelle_sl_nr',
#  'datum_pn',
#  'stoff_nr',
#  'probengut',
#  'messergebnis_c',
#  'messergebnis_hinweis',
#  'bestimmungsgrenze',
#  'masseinheit',
#  'trennverfahren',
#  'verfahren',
#  'vor_ort']

# %%
#df['messstell'] = df['Value'].str.replace(',', '.', regex=True)

# %%
# %time df_qual = pd.read_csv(gw_quality_pfname, sep = ";", encoding="cp1252", dtype = {"messergebnis_c":str ,"messergebnis_hinweis":str }, nrows = 5)
# Out:
# CPU times: total: 0 ns
# Wall time: 8.06 ms

# %%
df_qual
# Out:
#       sl_nr  messstelle_id  messstelle_sl_nr    datum_pn  stoff_nr  \
# 0  10472780      289002916             18994  1991-06-24      1247
# 1    758273       10203230               252  1990-09-18      2001
# 2    758278       10203230               252  1990-09-18      2010
# 3    758272       10203230               252  1990-09-18      2000
# 4    758267       10203230               252  1990-09-18      1343
#
#      probengut messergebnis_c  \
# 0  Grundwasser       <0,03049
# 1  Grundwasser       <0,10000
# 2  Grundwasser       <0,10000
# 3  Grundwasser      <10,00000
# 4  Grundwasser      <10,00000
#
#                                 messergebnis_hinweis  bestimmungsgrenze  \
# 0  Konzentration zu gering zur Bestimmung        ...                NaN
# 1  Konzentration zu gering zur Bestimmung        ...                NaN
# 2  Konzentration zu gering zur Bestimmung        ...                NaN
# 3  Konzentration zu gering zur Bestimmung        ...                NaN
# 4  Konzentration zu gering zur Bestimmung        ...                NaN
#
#   masseinheit trennverfahren                                verfahren vor_ort
# 0        mg/l   Gesamtgehalt                                      NaN
# 1        µg/l   Gesamtgehalt                    DIN 38407-F4 MAI 1988
# 2        µg/l   Gesamtgehalt                    DIN 38407-F4 MAI 1988
# 3        µg/l   Gesamtgehalt                    DIN 38407-F4 MAI 1988
# 4        µg/l   Gesamtgehalt  DIN 38409-H14 MAERZ 1985, ABSCHN. 8.2.2

# %%
df_qual["messergebnis_c"] = df_qual["messergebnis_c"].str.replace(',', '.', regex=True)
df_qual
# Out:
#       sl_nr  messstelle_id  messstelle_sl_nr    datum_pn  stoff_nr  \
# 0  10472780      289002916             18994  1991-06-24      1247
# 1    758273       10203230               252  1990-09-18      2001
# 2    758278       10203230               252  1990-09-18      2010
# 3    758272       10203230               252  1990-09-18      2000
# 4    758267       10203230               252  1990-09-18      1343
#
#      probengut messergebnis_c  \
# 0  Grundwasser       <0.03049
# 1  Grundwasser       <0.10000
# 2  Grundwasser       <0.10000
# 3  Grundwasser      <10.00000
# 4  Grundwasser      <10.00000
#
#                                 messergebnis_hinweis  bestimmungsgrenze  \
# 0  Konzentration zu gering zur Bestimmung        ...                NaN
# 1  Konzentration zu gering zur Bestimmung        ...                NaN
# 2  Konzentration zu gering zur Bestimmung        ...                NaN
# 3  Konzentration zu gering zur Bestimmung        ...                NaN
# 4  Konzentration zu gering zur Bestimmung        ...                NaN
#
#   masseinheit trennverfahren                                verfahren vor_ort
# 0        mg/l   Gesamtgehalt                                      NaN
# 1        µg/l   Gesamtgehalt                    DIN 38407-F4 MAI 1988
# 2        µg/l   Gesamtgehalt                    DIN 38407-F4 MAI 1988
# 3        µg/l   Gesamtgehalt                    DIN 38407-F4 MAI 1988
# 4        µg/l   Gesamtgehalt  DIN 38409-H14 MAERZ 1985, ABSCHN. 8.2.2

# %%
df_qual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sl_nr                 5 non-null      int64
#  1   messstelle_id         5 non-null      int64
#  2   messstelle_sl_nr      5 non-null      int64
#  3   datum_pn              5 non-null      object
#  4   stoff_nr              5 non-null      int64
#  5   probengut             5 non-null      object
#  6   messergebnis_c        5 non-null      object
#  7   messergebnis_hinweis  5 non-null      object
#  8   bestimmungsgrenze     0 non-null      float64
#  9   masseinheit           5 non-null      object
#  10  trennverfahren        5 non-null      object
#  11  verfahren             4 non-null      object
#  12  vor_ort               5 non-null      object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 652.0+ bytes

# %% [markdown]
# **The complete CSV file with the measured values of the chemical analyses comprises more than 3.6 million measured values!**

# %%
# Wall time: 13 s
# %time df_qual = pd.read_csv(gw_quality_pfname, sep = ";", encoding="cp1252", index_col=["sl_nr"], \
                            dtype = {"messergebnis_c":str ,"messergebnis_hinweis":str }, \
                            parse_dates = ["datum_pn"])
# Out:
# CPU times: total: 2.42 s
# Wall time: 2.56 s

# %%
df_qual.shape
# Out:
# (714299, 12)

# %%
df_qual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714299 entries, 10472780 to 12763519
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   messstelle_id         714299 non-null  int64
#  1   messstelle_sl_nr      714299 non-null  int64
#  2   datum_pn              714299 non-null  datetime64[ns]
#  3   stoff_nr              714299 non-null  int64
#  4   probengut             714299 non-null  object
#  5   messergebnis_c        714299 non-null  object
#  6   messergebnis_hinweis  714299 non-null  object
#  7   bestimmungsgrenze     24065 non-null   object
#  8   masseinheit           714299 non-null  object
#  9   trennverfahren        714299 non-null  object
#  10  verfahren             521715 non-null  object
#  11  vor_ort               714299 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 70.8+ MB

# %%
# duplicate sl_nr values? Can it be a unique index?
# Result should be empty
print(df_qual[df_qual.index.duplicated()])
# Out:
# Empty DataFrame
# Columns: [messstelle_id, messstelle_sl_nr, datum_pn, stoff_nr, probengut, messergebnis_c, messergebnis_hinweis, bestimmungsgrenze, masseinheit, trennverfahren, verfahren, vor_ort]
# Index: []

# %% [markdown]
# ## Time Series Example

# %%
df_qual
# Out:
#           messstelle_id  messstelle_sl_nr   datum_pn  stoff_nr    probengut  \
# sl_nr
# 10472780      289002916             18994 1991-06-24      1247  Grundwasser
# 758273         10203230               252 1990-09-18      2001  Grundwasser
# 758278         10203230               252 1990-09-18      2010  Grundwasser
# 758272         10203230               252 1990-09-18      2000  Grundwasser
# 758267         10203230               252 1990-09-18      1343  Grundwasser
# ...                 ...               ...        ...       ...          ...
# 2148723        30302626              8174 1998-07-21      1266  Grundwasser
# 2148724        30302626              8174 1998-07-21      1061  Grundwasser
# 12244907       30302626              8174 1998-07-21      1244  Grundwasser
# 12520549       30302626              8174 1998-07-21      1246  Grundwasser
# 12763519       30302626              8174 1998-07-21      1248  Grundwasser
#
#          messergebnis_c                               messergebnis_hinweis  \
# sl_nr
# 10472780       <0,03049  Konzentration zu gering zur Bestimmung        ...
# 758273         <0,10000  Konzentration zu gering zur Bestimmung        ...
# 758278         <0,10000  Konzentration zu gering zur Bestimmung        ...
# 758272        <10,00000  Konzentration zu gering zur Bestimmung        ...
# 758267        <10,00000  Konzentration zu gering zur Bestimmung        ...
# ...                 ...                                                ...
# 2148723         0,01000                                                ...
# 2148724         6,70000                                                ...
# 12244907        3,36452                                                ...
# 12520549        0,02300                                                ...
# 12763519        0,29624                                                ...
#
#          bestimmungsgrenze masseinheit trennverfahren  \
# sl_nr
# 10472780               NaN        mg/l   Gesamtgehalt
# 758273                 NaN        µg/l   Gesamtgehalt
# 758278                 NaN        µg/l   Gesamtgehalt
# 758272                 NaN        µg/l   Gesamtgehalt
# 758267                 NaN        µg/l   Gesamtgehalt
# ...                    ...         ...            ...
# 2148723                NaN        mg/l  Membranfilter
# 2148724                NaN           -   Gesamtgehalt
# 12244907               NaN        mg/l  Membranfilter
# 12520549               NaN        mg/l   Gesamtgehalt
# 12763519               NaN        mg/l   Gesamtgehalt
#
#                                          verfahren vor_ort
# sl_nr
# 10472780                                       NaN
# 758273                       DIN 38407-F4 MAI 1988
# 758278                       DIN 38407-F4 MAI 1988
# 758272                       DIN 38407-F4 MAI 1988
# 758267     DIN 38409-H14 MAERZ 1985, ABSCHN. 8.2.2
# ...                                            ...     ...
# 2148723               DIN 38405-D11-3 OKTOBER 1983
# 2148724                   DIN 38404-C5 JANUAR 1984      ja
# 12244907              DIN 38405-D20 SEPTEMBER 1991
# 12520549  DIN 38405-D10 02.81,DIN EN 26777 04.1993
# 12763519               DIN 38406-E5-2 OKTOBER 1983
#
# [714299 rows x 12 columns]

# %%
# time series example
# stoff_nr=1244 ->"Nitrat"
idx = (df_qual["messstelle_id"] == 30302626) & (df_qual["stoff_nr"] == 1244)
df_qual.loc[idx,["datum_pn", "messergebnis_c"]].sort_values("datum_pn")
# Out:
#            datum_pn messergebnis_c
# sl_nr
# 12242606 1996-03-18       <1,32810
# 12153491 1996-09-03       <1,32810
# 12153509 1997-04-04       <1,32810
# 12153524 1997-09-09       <1,32810
# 12244853 1998-03-12        4,42700
# 12244907 1998-07-21        3,36452
# 12244901 1999-06-16        2,78901
# 12245004 1999-12-17        2,83328

# %% [markdown]
# ### Tests for different measurement value string cases
#
# ```
# (1)   "1.00" (is_float)
# (2)  "<1.00" (is_less)
# (3)  ">1.00" (is_greater)
# ```

# %%
# check if string can be converted to float
def is_float(element: str) -> bool:
    try:
        float(element)
        return True
    except ValueError:
        return False

# %%
# check if string starts with '<'
def is_less(element: str) -> bool:
    return element[0] == "<"

# %%
# check if string starts with '>'
def is_greater(element: str) -> bool:
    return element[0] == ">"

# %%
print("is_float()")
print(is_float("<1.234"))
print(is_float(">1.234"))
print(is_float("-1.234"))
# Out:
# is_float()
# False
# False
# True

# %%
# Some test applications
print("is_less()")
print(is_less("<1.234"))
print(is_less(">1.234"))
print(is_less("1.234"))
print("is_greater()")
print(is_greater("<1.234"))
print(is_greater(">1.234"))
print(is_greater("1.234"))
print("is_float()")
print(is_float("<1.234"))
print(is_float(">1.234"))
print(is_float("1.234"))
# Out:
# is_less()
# True
# False
# False
# is_greater()
# False
# True
# False
# is_float()
# False
# False
# True

# %%
# Apply the tests and create Boolean indexes
# %time idx_mess_is_float   = df_qual["messergebnis_c"].apply(is_float)
# %time idx_mess_is_less    = df_qual["messergebnis_c"].apply(is_less)
# %time idx_mess_is_greater = df_qual["messergebnis_c"].apply(is_greater)
# Out:
# CPU times: total: 1.34 s
# Wall time: 1.38 s
# CPU times: total: 188 ms
# Wall time: 185 ms
# CPU times: total: 78.1 ms
# Wall time: 179 ms

# %%
print(idx_mess_is_greater)
# Out:
# sl_nr
# 10472780    False
# 758273      False
# 758278      False
# 758272      False
# 758267      False
#             ...
# 2148723     False
# 2148724     False
# 12244907    False
# 12520549    False
# 12763519    False
# Name: messergebnis_c, Length: 714299, dtype: bool

# %%
# Print records which are neither less nor greater nor float -> should be empty data frame
assert df_qual[~idx_mess_is_less & ~idx_mess_is_greater & ~idx_mess_is_float].shape[0] == 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[93], line 2
#       1 # Print records which are neither less nor greater nor float -> should be empty data frame
# ----> 2 assert df_qual[~idx_mess_is_less & ~idx_mess_is_greater & ~idx_mess_is_float].shape[0] == 0
#
# AssertionError:

# %%
# Dataframe should be empty
print(df_qual[~idx_mess_is_less & ~idx_mess_is_greater & ~idx_mess_is_float])
# Out:
#           messstelle_id  messstelle_sl_nr   datum_pn  stoff_nr    probengut  \
# sl_nr
# 758239         10203230               252 1990-09-18      1011  Grundwasser
# 758240         10203230               252 1990-09-18      1061  Grundwasser
# 758241         10203230               252 1990-09-18      1061  Grundwasser
# 758242         10203230               252 1990-09-18      1082  Grundwasser
# 758243         10203230               252 1990-09-18      1082  Grundwasser
# ...                 ...               ...        ...       ...          ...
# 2148723        30302626              8174 1998-07-21      1266  Grundwasser
# 2148724        30302626              8174 1998-07-21      1061  Grundwasser
# 12244907       30302626              8174 1998-07-21      1244  Grundwasser
# 12520549       30302626              8174 1998-07-21      1246  Grundwasser
# 12763519       30302626              8174 1998-07-21      1248  Grundwasser
#
#          messergebnis_c                               messergebnis_hinweis  \
# sl_nr
# 758239          9,50000                                                ...
# 758240          7,10000                                                ...
# 758241          7,10000                                                ...
# 758242         59,00000                                                ...
# 758243         59,00000                                                ...
# ...                 ...                                                ...
# 2148723         0,01000                                                ...
# 2148724         6,70000                                                ...
# 12244907        3,36452                                                ...
# 12520549        0,02300                                                ...
# 12763519        0,29624                                                ...
#
#          bestimmungsgrenze masseinheit trennverfahren  \
# sl_nr
# 758239                 NaN          °C   Gesamtgehalt
# 758240                 NaN           -   Gesamtgehalt
# 758241                 NaN           -   Gesamtgehalt
# 758242                 NaN        mS/m   Gesamtgehalt
# 758243                 NaN        mS/m   Gesamtgehalt
# ...                    ...         ...            ...
# 2148723                NaN        mg/l  Membranfilter
# 2148724                NaN           -   Gesamtgehalt
# 12244907               NaN        mg/l  Membranfilter
# 12520549               NaN        mg/l   Gesamtgehalt
# 12763519               NaN        mg/l   Gesamtgehalt
#
#                                          verfahren vor_ort
# sl_nr
# 758239                  DIN 38404-C4 DEZEMBER 1976      ja
# 758240                   DEV C5-2 4.LIEFERUNG 1966
# 758241                    DIN 38404-C5 JANUAR 1984      ja
# 758242                 DIN 38404-C8 SEPTEMBER 1982
# 758243    DIN 38404-C8 09.1985;DIN EN27888 11.1993      ja
# ...                                            ...     ...
# 2148723               DIN 38405-D11-3 OKTOBER 1983
# 2148724                   DIN 38404-C5 JANUAR 1984      ja
# 12244907              DIN 38405-D20 SEPTEMBER 1991
# 12520549  DIN 38405-D10 02.81,DIN EN 26777 04.1993
# 12763519               DIN 38406-E5-2 OKTOBER 1983
#
# [402875 rows x 12 columns]

# %%
# res = (~idx_mess_is_less & ~idx_mess_is_greater & ~idx_mess_is_float).value_counts()
res = (idx_mess_is_less | idx_mess_is_greater | idx_mess_is_float).value_counts()
res
# Out:
# messergebnis_c
# False    402875
# True     311424
# Name: count, dtype: int64

# %% [markdown]
# ## Convert measurement results to float. Fill the limit column.

# %%
# %time df_qual.loc[idx_mess_is_float,"messergebnis_num"] = df_qual.loc[idx_mess_is_float,"messergebnis_c"].astype(float)
# %time df_qual.loc[idx_mess_is_float,"grenze"] = "="

# %time df_qual.loc[idx_mess_is_less,"messergebnis_num"] = df_qual.loc[idx_mess_is_less,"messergebnis_c"].str[1:].astype(float)
# %time df_qual.loc[idx_mess_is_less,"grenze"] = "<"

# %time df_qual.loc[idx_mess_is_greater,"messergebnis_num"] = df_qual.loc[idx_mess_is_greater,"messergebnis_c"].str[1:].astype(float)
# %time df_qual.loc[idx_mess_is_greater,"grenze"] = ">"
# Out:
# CPU times: total: 0 ns
# Wall time: 10.2 ms
# CPU times: total: 15.6 ms
# Wall time: 34.3 ms
# <timed exec>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '=' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:1
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '0,03049'
# CPU times: total: 0 ns
# Wall time: 15.5 ms
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:1
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\envs\geo\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '0,00000'
# CPU times: total: 0 ns
# Wall time: 2 ms

# %%
print("Different values for column 'grenze'")
print(df_qual["grenze"].value_counts())
# Out:
# Different values for column 'grenze'
# grenze
# <    311420
# >         4
# Name: count, dtype: int64

# %%
df_qual[idx_mess_is_greater][["messergebnis_c", "messergebnis_num", "grenze"]].head()
# Out:
#         messergebnis_c  messergebnis_num grenze
# sl_nr
# 6177232       >0,00000               NaN      >
# 6177402       >0,00000               NaN      >
# 6177268       >0,00000               NaN      >
# 6177316       >0,00000               NaN      >

# %%
df_qual[idx_mess_is_less][["messergebnis_c", "messergebnis_num", "grenze"]].head()
# Out:
#          messergebnis_c  messergebnis_num grenze
# sl_nr
# 10472780       <0,03049               NaN      <
# 758273         <0,10000               NaN      <
# 758278         <0,10000               NaN      <
# 758272        <10,00000               NaN      <
# 758267        <10,00000               NaN      <

# %%
df_qual[idx_mess_is_float][["messergebnis_c", "messergebnis_num", "grenze"]].head()
# Out:
# Empty DataFrame
# Columns: [messergebnis_c, messergebnis_num, grenze]
# Index: []

# %%
# Reason for not being float? XOR: A ^ B
#idx = (~idx_mess_is_float ^ idx_mess_is_less) # These are non-floats which are be less at the same time => greater
#df_qual[idx]

# %%
# Reason for not being float? XOR
#idx = (~idx_mess_is_float ^ idx_mess_is_greater)
#df_qual[idx]

# %%
df_qual[df_qual["messergebnis_num"]<0]
# Out:
# Empty DataFrame
# Columns: [messstelle_id, messstelle_sl_nr, datum_pn, stoff_nr, probengut, messergebnis_c, messergebnis_hinweis, bestimmungsgrenze, masseinheit, trennverfahren, verfahren, vor_ort, messergebnis_num, grenze]
# Index: []

# %% [markdown]
# ## Upload the data to the database with `df.to_sql()`

# %%
import sqlalchemy
engine = sqlalchemy.create_engine("postgresql+psycopg://env_master:M123xyz@localhost/env_db")

# %%
# the default to_sql() / sqlalchemy method using psycopg2 (default PG driver) ...
# on my laptop:
# Approx. Wall time: 4min 32s 

# %time df_qual.to_sql(con=engine, name="gw_meas", schema="gw", if_exists="fail")
#%time df_qual.to_sql(con=engine, name="gw_meas", schema="gw", if_exists="replace")

# %% [markdown]
# ## Search for duplicates! Primary key is not straight forward!

# %%
# %load_ext sql

# %%
print("Connect")
# %sql postgresql://env_master:M123xyz@localhost/env_db

# %%
# %%sql
# alter table gw.gw_meas add constraint pk_gw_meas primary key (messstelle_id, datum_pn, stoff_nr)

# %%
# %%sql
# select * from gw.gw_meas where (messstelle_id, datum_pn, stoff_nr) = (73537317, '1990-08-17 00:00:00', 1061)

# %% [markdown]
# Is `sl_nr` unique?

# %%
# %%sql
# select sl_nr,count(sl_nr) as count from gw.gw_meas group by sl_nr having count(sl_nr) > 1;

# %% [markdown]
# **`sl_nr` is a non-smart primary key ...**

# %%
# %%sql
# alter table gw.gw_meas add constraint pk_gw_meas primary key (sl_nr)

# %% [markdown]
# ## Create some indexes to improve database performance

# %%
# %%sql
# create index idx_gw_meas_messstelle_id_datum_pn on gw.gw_meas (messstelle_id, datum_pn)

# %%
# %%sql
# create index idx_gw_meas_datum_pn_meas_messstelle on gw.gw_meas (datum_pn, messstelle_id)

# %%
# %%sql
# create index idx_gw_meas_stoff_nr on gw.gw_meas (stoff_nr)

# %%
# %%sql
# create index idx_gw_meas_datum_pn_stoff_nr on gw.gw_meas (datum_pn, stoff_nr);

# %%
# %%time
# %sql select count(*) from gw.gw_meas

# %%
# %%time
# %sql select messstelle_id, datum_pn, count(*) as count from gw.gw_meas group by (messstelle_id, datum_pn) limit 20

# %% [markdown]
# **ATTENTION! 140515 anlyses were performed with more than one method!**

# %%
#%%sql
#SELECT messstelle_id, datum_pn, stoff_nr, COUNT(*) AS Count
#FROM gw.gw_meas
#GROUP BY messstelle_id, datum_pn, stoff_nr
#HAVING COUNT(*) > 1;

# %%
# %%sql
# SELECT t1.* from gw.gw_meas t1, gw.gw_meas t2 
# where 
# t1.messstelle_id = t2.messstelle_id
# and
# t1.datum_pn = t2.datum_pn
# and
# t1.stoff_nr = t2.stoff_nr
# and
# t1.verfahren <> t2.verfahren
# and

# t1.sl_nr = (select max(sl_nr) from gw.gw_meas t3 
# where
# t1.messstelle_id = t3.messstelle_id
# and
# t1.datum_pn = t3.datum_pn
# and
# t1.stoff_nr = t3.stoff_nr
# )

# limit 1000

# %% [markdown]
# # Import `katalog_stoff`
#
# It is in another notebook!

# %%
# %%sql
# select * from gw.katalog_stoff where name like 'N%'

# %%
# %%sql
# alter table gw.katalog_stoff add constraint pk_kat_stoff primary key (stoff_nr)

# %%
# %%sql
# create index idx_kat_stoff_name on gw.katalog_stoff (name)

# %%
# %%sql
# select * from gw.gw_stations limit 3

# %% [markdown]
# # Create Views!

# %%
# %%sql
# drop view gw.v_gw_stations_wrrl_chemie

# %%
# %%sql
# create view gw.v_gw_stations_wrrl_chemie as
# select * from gw.gw_stations
# where im_wrrl_messnetz_chemie = 'ja'
# and freigabe_chemie = 'ja'

# %%
# %%sql
# select count(*) from gw.v_gw_stations_wrrl_chemie

# %%
# %%sql
# select geometry, messstelle_id, name, genau, im_wrrl_messnetz_chemie, im_wrrl_messnetz_wasserstand from gw.gw_stations
# limit 10

# %%
# %%sql
# select *
# from gw.gw_meas
# limit 1

# %%
# %%sql
# select sl_nr, messstelle_id, stoff_nr, datum_pn, grenze, messergebnis_num, masseinheit
# from gw.gw_meas
# limit 3

# %%
# %%sql
# select
# st.geometry, st.messstelle_id, st.name, st.genau, st.im_wrrl_messnetz_chemie, st.im_wrrl_messnetz_wasserstand,
# m.sl_nr, m.stoff_nr,  p.name as stoffname, m.datum_pn, m.grenze, m.messergebnis_num, m.masseinheit
# from gw.gw_stations st, gw.gw_meas m, gw.katalog_stoff p
# where st.messstelle_id = m.messstelle_id
# and m.stoff_nr = p.stoff_nr
# limit 2

# %%
# %%sql
# drop view gw.gw_station_series

# %%
# %%sql
# create or replace view gw.gw_station_series as
# select
# m.sl_nr as fid, st.geometry, st.messstelle_id, st.name, st.genau, st.im_wrrl_messnetz_chemie, st.im_wrrl_messnetz_wasserstand,
# m.sl_nr, m.stoff_nr,  p.name as stoffname, m.datum_pn, m.grenze, m.messergebnis_num, m.masseinheit
# from gw.gw_stations st, gw.gw_meas m, gw.katalog_stoff p
# where st.messstelle_id = m.messstelle_id
# and m.stoff_nr = p.stoff_nr
# order by messstelle_id, stoff_nr, datum_pn

# %%
# %%sql
# select * from gw.katalog_stoff where name = 'Nitrat'

# %%
# %%sql
# drop view gw.gw_station_nitrat_series

# %%
# %%sql
# select distinct (im_wrrl_messnetz_chemie) from gw.gw_stations

# %%
# %%sql
# drop view gw.v_gw_station_nitrat

# %%
# %%sql
# create or replace view gw.v_gw_station_nitrat as
# select
# m.sl_nr as fid, st.geometry, st.messstelle_id, st.name, st.genau, st.im_wrrl_messnetz_chemie, st.im_wrrl_messnetz_wasserstand,
# m.sl_nr, m.stoff_nr,  p.name as stoffname, m.datum_pn, m.grenze, m.messergebnis_num, m.masseinheit
# from gw.gw_stations st, gw.gw_meas m, gw.katalog_stoff p
# where st.im_wrrl_messnetz_chemie = 'ja'
# and p.name = 'Nitrat'
# and m.stoff_nr = p.stoff_nr
# and st.messstelle_id = m.messstelle_id
# order by messstelle_id, stoff_nr, datum_pn

# %%
# %%sql
# create or replace view gw.v_gw_station_sulfat as
# select
# m.sl_nr as fid, st.geometry, st.messstelle_id, st.name, st.genau, st.im_wrrl_messnetz_chemie, st.im_wrrl_messnetz_wasserstand,
# m.sl_nr, m.stoff_nr,  p.name as stoffname, m.datum_pn, m.grenze, m.messergebnis_num, m.masseinheit
# from gw.gw_stations st, gw.gw_meas m, gw.katalog_stoff p
# where st.im_wrrl_messnetz_chemie = 'ja'
# and p.name = 'Sulfat'
# and m.stoff_nr = p.stoff_nr
# and st.messstelle_id = m.messstelle_id
# order by messstelle_id, stoff_nr, datum_pn

# %%
# %sql select count(*) from gw.v_gw_station_sulfat

# %% [markdown]
# ## Exercises
#
# 1) Add the PostGIS table `gw.gw_stations` as vector layer to QGIS.
#
# 2) Use df.to_sql() to upload the table with the catalog (file `katalog_stoff.csv` in the data directory) of the analyzed quantities (substances, physico-chemical parameters, e.g. NO3- concentation (nitrate), pH, air temperature (can be neg.), etc.)
#
# 3) Add the catalog with municipalities (file `katalog_gemeinde.csv`)
#
# 4) SQL: Create a view joining the gw station table with gw meas table and gw parameter table. (A bit difficult. We have not discussed it yet.)
#
# 5) Create a reduced view for nitrate only joining the gw station table with gw meas table and gw parameter table.
#
# 6) Try to get the station-nitrate table into QGIS using the PostGIS interface.
#
# SQL: Before you create the views create primary keys for the tables. i.e. `(messstelle_id)` for `gw_stations`,
# `(messstelle_id, stoff_nr, pna_datum)` for `gw_meas`.
